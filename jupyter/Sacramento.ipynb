# %%
import pandas as pd

# %%
df = pd.read_csv("data/sacramento/nhgis0001_csv/nhgis0001_ds104_1980_tract.csv")

# %%
df.head()
# Out:
#         GISJOIN  YEAR  REGIONA  DIVISIONA    STATE  STATEA   SMSAA   COUNTY  \
# 0  G01000100201  1980        3          6  Alabama       1  5240.0  Autauga
# 1  G01000100202  1980        3          6  Alabama       1  5240.0  Autauga
# 2  G01000100203  1980        3          6  Alabama       1  5240.0  Autauga
# 3  G01000100204  1980        3          6  Alabama       1  5240.0  Autauga
# 4  G01000100205  1980        3          6  Alabama       1  5240.0  Autauga
#
#    COUNTYA  CTY_SUBA   ...    C9D006  C9D007  C9D008  C9D009  C9D010  C9D011  \
# 0        1      20.0   ...         4       0       1       0       0       0
# 1        1      20.0   ...         2       1       0       0       0       0
# 2        1      20.0   ...         9       0       8       1       0       1
# 3        1      20.0   ...         7       1       0       1       0       1
# 4        1      20.0   ...         4       1       1       2       4       1
#
#    C9D012  C9D013  C9D014  C9D015
# ...

# %%
cali = df[df["STATE"]=="California"]
cali.head()
# Out:
#            GISJOIN  YEAR  REGIONA  DIVISIONA       STATE  STATEA   SMSAA  \
# 1600  G06000104001  1980        4          9  California       6  7360.0
# 1601  G06000104002  1980        4          9  California       6  7360.0
# 1602  G06000104003  1980        4          9  California       6  7360.0
# 1603  G06000104004  1980        4          9  California       6  7360.0
# 1604  G06000104005  1980        4          9  California       6  7360.0
#
#        COUNTY  COUNTYA  CTY_SUBA   ...    C9D006  C9D007  C9D008  C9D009  \
# 1600  Alameda        1      50.0   ...        28      66       1       6
# 1601  Alameda        1      50.0   ...        22      56      14       5
# 1602  Alameda        1      50.0   ...        36     100      31       4
# 1603  Alameda        1      50.0   ...        67      56      45      10
# 1604  Alameda        1      50.0   ...        41      53      14       1
#
#       C9D010  C9D011  C9D012  C9D013  C9D014  C9D015
# ...
